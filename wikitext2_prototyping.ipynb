# %%
from datasets import load_dataset

ds_raw = load_dataset("Salesforce/wikitext", "wikitext-2-raw-v1")
ds = load_dataset("Salesforce/wikitext", "wikitext-2-v1")
# Out:
# test-00000-of-00001.parquet:   0%|          | 0.00/685k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/6.07M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/618k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/4358 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/36718 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3760 [00:00<?, ? examples/s]

# %%
import transformers
name = 'roberta-base'
tokenizer = transformers.AutoTokenizer.from_pretrained(name,device='cpu')
pipe = transformers.pipeline('fill-mask', model=name, tokenizer=tokenizer)
# Out:
# Device set to use cpu

# %%
tokenized = tokenizer(['Townsend recorded a Noisescapes demo and sent copies to various record labels .'])
tokenized['input_ids'][0][-2] = tokenizer.mask_token_id
print(tokenizer.decode(tokenized['input_ids'][0]))
pipe(tokenizer.decode(tokenized['input_ids'][0]))
# Out:
# <s>Townsend recorded a Noisescapes demo and sent copies to various record labels<mask></s>
# [{'score': 0.8297228813171387,
#   'token': 4,
#   'token_str': '.',
#   'sequence': 'Townsend recorded a Noisescapes demo and sent copies to various record labels.'},
#  {'score': 0.15780211985111237,
#   'token': 35,
#   'token_str': ':',
#   'sequence': 'Townsend recorded a Noisescapes demo and sent copies to various record labels:'},
#  {'score': 0.0013476395979523659,
#   'token': 72,
#   'token_str': '."',
#   'sequence': 'Townsend recorded a Noisescapes demo and sent copies to various record labels."'},
#  {'score': 0.0010444007348269224,
#   'token': 4832,
#   'token_str': ' :',
#   'sequence': 'Townsend recorded a Noisescapes demo and sent copies to various record labels :'},
#  {'score': 0.000980676501058042,
#   'token': 734,
#   'token_str': '...',
#   'sequence': 'Townsend recorded a Noisescapes demo and sent copies to various record labels...'}]

# %%
print(ds['train']['text'][1500:1510])
print(ds_raw['train']['text'][1500:1510])
# Out:
# [" Townsend recorded a Noisescapes demo and sent copies to various record labels . <unk> Records responded to Townsend with a record deal and Townsend began work on what was to be the first Noisescapes album , Promise . Shortly afterward , the label introduced him to musician Steve Vai . Impressed with Townsend 's vocal work , Vai offered him the role of the lead vocalist on his new album Sex and Religion . After recording Sex and Religion , Townsend accompanied Vai on a world tour in support of the album . Townsend soon landed a second touring gig , this time with the opening band of Vai 's tour , the Wildhearts . He played live with the band throughout half of 1994 in Europe , and appeared as a guest musician on their single <unk> . <unk> , the band 's frontman , remained close friends with Townsend , later co @-@ writing several songs on Infinity and the <unk> + 4 <unk> EP . \n", ' While on tour with the Wildhearts , Townsend formed a short @-@ lived thrash metal project with Metallica \'s then @-@ bassist Jason Newsted . The band , known as IR8 , featured Newsted on vocals and bass , Townsend on guitar , and Tom Hunting of Exodus on drums . The group recorded a few songs together , although Townsend says that they never intended to go further than that . " People heard about it and thought we wanted to put out a CD , which is absolutely not true , " he explains . " People took this project way too seriously . " A demo tape was put together , but the material was not released until 2002 , when Newsted published the IR8 vs. <unk> compilation . \n', ' Though Townsend was proud of what he had accomplished so early in his career , he was discouraged by his experience with the music industry . " I was becoming a product of somebody else \'s imagination , and it was mixing with my own personality , " he later reflected . " This combination was appalling . " He pushed to get his own projects off the ground . Despite getting notable touring gigs with other musicians , however , Townsend continued to face rejection of his own music . <unk> Records dropped Noisescapes from their label shortly after Townsend accepted Vai \'s offer , seeing no commercial appeal in Townsend \'s music . " I have a <unk> they only offered me a deal to get me to sing with Steve , " he <unk> . While touring with the Wildhearts , Townsend received a phone call from an A & R representative for Roadrunner Records , expressing an interest in his demos and an intention to sign him . The offer was ultimately rescinded by the head of Roadrunner , who regarded Townsend \'s recordings as " just noise " . \n', '', ' = = = Heavy as a Really Heavy Thing through Infinity ( 1994 – 1998 ) = = = \n', '', ' In 1994 , Century Media Records offered Townsend a contract to make " some extreme albums " . He agreed to a five @-@ album deal with the record label , and also provided much of the guitar work on the 1994 album Millennium and the 1995 album Hard Wired by Vancouver industrial band Front Line Assembly . Townsend began to record material under the pseudonym Strapping Young Lad . He avoided using his real name at this point in career , looking for a fresh start after his high @-@ profile Vai gig . " At the beginning , I wanted to avoid at all cost to use my name because I was known as the singer for Steve Vai and it wasn \'t the best publicity to have , " he later explained . " I was playing somebody else \'s music and I was judged in respect to that music . " Townsend produced and performed nearly all the instruments on the debut studio album , Heavy as a Really Heavy Thing , which was released in April 1995 . \n', ' Following the release of the record , Townsend and several other musician friends he knew in Vancouver recorded his first solo album in 1996 entitled <unk> <unk> – <unk> on <unk> . Written and recorded in under a month , the album was produced as a parody of punk rock bands and documents the act of selling out for mainstream success . Townsend founded his own ...
# [" Townsend recorded a Noisescapes demo and sent copies to various record labels . Relativity Records responded to Townsend with a record deal and Townsend began work on what was to be the first Noisescapes album , Promise . Shortly afterward , the label introduced him to musician Steve Vai . Impressed with Townsend 's vocal work , Vai offered him the role of the lead vocalist on his new album Sex and Religion . After recording Sex and Religion , Townsend accompanied Vai on a world tour in support of the album . Townsend soon landed a second touring gig , this time with the opening band of Vai 's tour , the Wildhearts . He played live with the band throughout half of 1994 in Europe , and appeared as a guest musician on their single Urge . Ginger , the band 's frontman , remained close friends with Townsend , later co @-@ writing several songs on Infinity and the Christeen + 4 Demos EP . \n", ' While on tour with the Wildhearts , Townsend formed a short @-@ lived thrash metal project with Metallica \'s then @-@ bassist Jason Newsted . The band , known as IR8 , featured Newsted on vocals and bass , Townsend on guitar , and Tom Hunting of Exodus on drums . The group recorded a few songs together , although Townsend says that they never intended to go further than that . " People heard about it and thought we wanted to put out a CD , which is absolutely not true , " he explains . " People took this project way too seriously . " A demo tape was put together , but the material was not released until 2002 , when Newsted published the IR8 vs. Sexoturica compilation . \n', ' Though Townsend was proud of what he had accomplished so early in his career , he was discouraged by his experience with the music industry . " I was becoming a product of somebody else \'s imagination , and it was mixing with my own personality , " he later reflected . " This combination was appalling . " He pushed to get his own projects off the ground . Despite getting notable touring gigs with other musicians , however , Townsend continued to face rejection of his own music . Relativity Records dropped Noisescapes from their label shortly after Townsend accepted Vai \'s offer , seeing no commercial appeal in Townsend \'s music . " I have a hunch they only offered me a deal to get me to sing with Steve , " he mused . While touring with the Wildhearts , Townsend received a phone call from an A & R representative for Roadrunner Records , expressing an interest in his demos and an intention to sign him . The offer was ultimately rescinded by the head of Roadrunner , who regarded Townsend \'s recordings as " just noise " . \n', '', ' = = = Heavy as a Really Heavy Thing through Infinity ( 1994 – 1998 ) = = = \n', '', ' In 1994 , Century Media Records offered Townsend a contract to make " some extreme albums " . He agreed to a five @-@ album deal with the record label , and also provided much of the guitar work on the 1994 album Millennium and the 1995 album Hard Wired by Vancouver industrial band Front Line Assembly . Townsend began to record material under the pseudonym Strapping Young Lad . He avoided using his real name at this point in career , looking for a fresh start after his high @-@ profile Vai gig . " At the beginning , I wanted to avoid at all cost to use my name because I was known as the singer for Steve Vai and it wasn \'t the best publicity to have , " he later explained . " I was playing somebody else \'s music and I was judged in respect to that music . " Townsend produced and performed nearly all the instruments on the debut studio album , Heavy as a Really Heavy Thing , which was released in April 1995 . \n', ' Following the release of the record , Townsend and several other musician friends he knew in Vancouver recorded his first solo album in 1996 entitled Punky Brüster – Cooked on Phonics . Written and recorded in under a month , the album was produced as a parody of punk rock bands and documents the act of selling out for mainstream success .  ...

# %%
inp = ds_raw['train']['text'][1500]

#wikitext-2 was described in https://arxiv.org/pdf/1609.07843
# it was made with the moses tokenizer, plus a few minor enhancements, such as "8,600 -> 8 @,@ 600"

def normalize_text(str):
    str = str.replace('\n',' ')
    #removing double white space
    last = str
    first = True 
    while(not(last == str) or first):
        last = str
        str = str.replace("  "," ")
        first = False 
    #fixing adjoining @-@'s 
    joiners = ["-",","]
    for joiner in joiners:
        str = str.replace(" @"+joiner+"@ ",joiner)
    #fixing white space introduced by punctuation 
    puncts = ['.',',','?','!',':',';']
    for punct in puncts:
        str = str.replace(" " + punct, punct)
    #fixing clitics
    clitics = ["'s","'re","'ve","'ll","n't","'d","'m"]
    for clitic in clitics:
            str = str.replace(" "+clitic, clitic)
    return str 

import sacremoses 
moses_detokenizer = sacremoses.MosesDetokenizer(lang='en')

def normalize_text_moses(str):
    output = moses_detokenizer.detokenize(str.split(' '), return_str=True)
    output = output.replace(" @,@ ",",") # this was a custom comma introduced by the wikitext-2 dataset for numbers.
    return output

out = normalize_text(inp)
print(inp)
print(out)
out_moses = normalize_text_moses(inp)
print(out_moses)
# Out:
#  Townsend recorded a Noisescapes demo and sent copies to various record labels . Relativity Records responded to Townsend with a record deal and Townsend began work on what was to be the first Noisescapes album , Promise . Shortly afterward , the label introduced him to musician Steve Vai . Impressed with Townsend 's vocal work , Vai offered him the role of the lead vocalist on his new album Sex and Religion . After recording Sex and Religion , Townsend accompanied Vai on a world tour in support of the album . Townsend soon landed a second touring gig , this time with the opening band of Vai 's tour , the Wildhearts . He played live with the band throughout half of 1994 in Europe , and appeared as a guest musician on their single Urge . Ginger , the band 's frontman , remained close friends with Townsend , later co @-@ writing several songs on Infinity and the Christeen + 4 Demos EP .
#
#  Townsend recorded a Noisescapes demo and sent copies to various record labels. Relativity Records responded to Townsend with a record deal and Townsend began work on what was to be the first Noisescapes album, Promise. Shortly afterward, the label introduced him to musician Steve Vai. Impressed with Townsend's vocal work, Vai offered him the role of the lead vocalist on his new album Sex and Religion. After recording Sex and Religion, Townsend accompanied Vai on a world tour in support of the album. Townsend soon landed a second touring gig, this time with the opening band of Vai's tour, the Wildhearts. He played live with the band throughout half of 1994 in Europe, and appeared as a guest musician on their single Urge. Ginger, the band's frontman, remained close friends with Townsend, later co-writing several songs on Infinity and the Christeen + 4 Demos EP.
# Townsend recorded a Noisescapes demo and sent copies to various record labels. Relativity Records responded to Townsend with a record deal and Townsend began work on what was to be the first Noisescapes album, Promise. Shortly afterward, the label introduced him to musician Steve Vai. Impressed with Townsend's vocal work, Vai offered him the role of the lead vocalist on his new album Sex and Religion. After recording Sex and Religion, Townsend accompanied Vai on a world tour in support of the album. Townsend soon landed a second touring gig, this time with the opening band of Vai's tour, the Wildhearts. He played live with the band throughout half of 1994 in Europe, and appeared as a guest musician on their single Urge. Ginger, the band's frontman, remained close friends with Townsend, later co-writing several songs on Infinity and the Christeen + 4 Demos EP.

# %%
# Out:
# '8-600.'

# %%
import nltk.tokenize
nltk_tokenizer = nltk.tokenize.TreebankWordTokenizer()
out = nltk_tokenizer.tokenize("I wanna watch something")
nltk_detokenizer = nltk.tokenize.treebank.TreebankWordDetokenizer()
nltk_detokenizer.detokenize(out)
# Out:
# 'I wanna watch something'

# %%
#let's see if we can find all of the article headers. 
import re
pattern = r'^[^=]*=[^=]*=[^=]*\n$'
source = ds_raw['train']['text']
matches = [(i,string) for i,string in enumerate(source) if re.match(pattern,string)]
matches = [(i,string) for i,string in matches if i > 0 and i < len(source)-2 and source[i-1] == "" and source[i+1] == ""]
article_ranges = [(matches[i][0],matches[i+1][0]) for i in range(len(matches)-1)]
print(article_ranges)
for m in matches:
    print(source[m[0]-1:m[0]+2])
# Out:
# [(1, 51), (51, 133), (133, 271), (271, 287), (287, 316), (316, 406), (406, 433), (433, 464), (464, 480), (480, 507), (507, 557), (557, 610), (610, 628), (628, 748), (748, 799), (799, 913), (913, 944), (944, 976), (976, 1038), (1038, 1107), (1107, 1157), (1157, 1244), (1244, 1274), (1274, 1380), (1380, 1401), (1401, 1487), (1487, 1582), (1582, 1633), (1633, 1648), (1648, 1690), (1690, 1710), (1710, 1856), (1856, 1960), (1960, 1988), (1988, 2038), (2038, 2134), (2134, 2156), (2156, 2187), (2187, 2270), (2270, 2347), (2347, 2378), (2378, 2487), (2487, 2555), (2555, 2665), (2665, 2680), (2680, 2712), (2712, 2733), (2733, 2820), (2820, 2932), (2932, 3128), (3128, 3259), (3259, 3299), (3299, 3345), (3345, 3443), (3443, 3475), (3475, 3571), (3571, 3640), (3640, 3717), (3717, 3733), (3733, 3790), (3790, 3820), (3820, 3926), (3926, 3941), (3941, 4015), (4015, 4150), (4150, 4199), (4199, 4228), (4228, 4439), (4439, 4557), (4557, 4573), (4573, 4787), (4787, 4818), (4818, 4836), (4836, 5057), (5057, 5103), (5103, 5122), (5122, 5161), (5161, 5198), (5198, 5227), (5227, 5241), (5241, 5264), (5264, 5295), (5295, 5326), (5326, 5393), (5393, 5440), (5440, 5538), (5538, 5639), (5639, 5679), (5679, 5713), (5713, 5748), (5748, 5869), (5869, 5885), (5885, 5912), (5912, 5981), (5981, 6059), (6059, 6104), (6104, 6141), (6141, 6256), (6256, 6307), (6307, 6409), (6409, 6475), (6475, 6542), (6542, 6699), (6699, 6739), (6739, 6758), (6758, 6781), (6781, 6821), (6821, 6882), (6882, 6914), (6914, 6939), (6939, 6968), (6968, 6991), (6991, 7009), (7009, 7115), (7115, 7132), (7132, 7149), (7149, 7198), (7198, 7293), (7293, 7562), (7562, 7684), (7684, 7818), (7818, 7877), (7877, 8034), (8034, 8058), (8058, 8106), (8106, 8125), (8125, 8156), (8156, 8173), (8173, 8213), (8213, 8251), (8251, 8297), (8297, 8342), (8342, 8366), (8366, 8446), (8446, 8542), (8542, 8645), (8645, 8695), (8695, 8729), (8729, 8771), (8771, 8827), (8827, 8844), (8844, 8901), (8901, 8961), (8961, 9103), (9103, 9133), (9133, 9183), (9183, 9228), (9228, 9318), (9318, 9402), (9402, 9425), (9425, 9475), (9475, 9518), (9518, 9666), (9666, 9703), (9703, 9841), (9841, 9888), (9888, 9935), (9935, 9975), (9975, 10010), (10010, 10125), (10125, 10143), (10143, 10258), (10258, 10340), (10340, 10411), (10411, 10452), (10452, 10474), (10474, 10553), (10553, 10603), (10603, 10676), (10676, 10767), (10767, 10809), (10809, 10831), (10831, 10887), (10887, 10968), (10968, 11011), (11011, 11106), (11106, 11131), (11131, 11166), (11166, 11189), (11189, 11220), (11220, 11296), (11296, 11334), (11334, 11377), (11377, 11400), (11400, 11438), (11438, 11532), (11532, 11623), (11623, 11691), (11691, 11710), (11710, 11726), (11726, 11780), (11780, 11810), (11810, 11983), (11983, 12023), (12023, 12048), (12048, 12079), (12079, 12128), (12128, 12272), (12272, 12311), (12311, 12341), (12341, 12425), (12425, 12457), (12457, 12565), (12565, 12618), (12618, 12680), (12680, 12719), (12719, 12807), (12807, 12841), (12841, 12877), (12877, 12928), (12928, 12981), (12981, 13053), (13053, 13079), (13079, 13125), (13125, 13168), (13168, 13191), (13191, 13217), (13217, 13301), (13301, 13338), (13338, 13354), (13354, 13371), (13371, 13511), (13511, 13552), (13552, 13574), (13574, 13592), (13592, 13613), (13613, 13630), (13630, 13811), (13811, 13853), (13853, 13930), (13930, 13978), (13978, 14004), (14004, 14065), (14065, 14112), (14112, 14198), (14198, 14262), (14262, 14301), (14301, 14331), (14331, 14377), (14377, 14432), (14432, 14451), (14451, 14580), (14580, 14599), (14599, 14642), (14642, 14680), (14680, 14802), (14802, 14859), (14859, 14883), (14883, 14925), (14925, 14988), (14988, 15010), (15010, 15041), (15041, 15214), (15214, 15239), (15239, 15273), (15273, 15378), (15378, 15407), (15407, 15450), (15450, 15486), (15486, 15542), (15542, 15577), (15577, 15596), (15596, 15642), (15642, 15678), (15678, 15704), (15704, 15741), (15741, 15777), (15777, 15839), (15839, 16067), (16067, 16096), (16096, 16293), (16293, 16329), (1632 ...
# ['', ' = Valkyria Chronicles III = \n', '']
# ['', ' = Tower Building of the Little Rock Arsenal = \n', '']
# ['', ' = Cicely Mary Barker = \n', '']
# ['', " = Gambia women 's national football team = \n", '']
# ['', ' = Plain maskray = \n', '']
# ['', ' = 2011 – 12 Columbus Blue Jackets season = \n', '']
# ['', ' = Gregorian Tower = \n', '']
# ['', " = There 's Got to Be a Way = \n", '']
# ['', ' = Nebraska Highway 88 = \n', '']
# ['', ' = USS Atlanta ( 1861 ) = \n', '']
# ['', ' = Jacqueline Fernandez = \n', '']
# ['', ' = John Cullen = \n', '']
# ['', ' = SMS Erzherzog Ferdinand Max = \n', '']
# ['', ' = Ancient Egyptian deities = \n', '']
# ['', ' = South of Heaven = \n', '']
# ['', ' = General aviation in the United Kingdom = \n', '']
# ['', ' = SMS Zrínyi = \n', '']
# ['', ' = Geopyxis carbonaria = \n', '']
# ['', ' = Gold dollar = \n', '']
# ['', ' = Johnson – Corey – Chaykovsky reaction = \n', '']
# ['', ' = Treaty of Ciudad Juárez = \n', '']
# ['', ' = The Feast of the Goat = \n', '']
# ['', ' = Charles Eaton ( RAAF officer ) = \n', '']
# ['', ' = Tina Fey = \n', '']
# ['', ' = WASP @-@ 44 = \n', '']
# ['', ' = Elephanta Caves = \n', '']
# ['', ' = Devin Townsend = \n', '']
# ['', ' = Zagreb Synagogue = \n', '']
# ['', ' = 1806 Great Coastal hurricane = \n', '']
# ['', ' = Forward Intelligence Team = \n', '']
# ['', ' = Trinsey v. Pennsylvania = \n', '']
# ['', ' = Michael Jordan = \n', '']
# ['', ' = Polish culture during World War II = \n', '']
# ['', ' = Arihant @-@ class submarine = \n', '']
# ['', ' = SMS Markgraf = \n', '']
# ['', ' = Coldrum Long Barrow = \n', '']
# ['', ' = Soviet cruiser Krasnyi Kavkaz = \n', '']
# ['', ' = Rhode Island Route 4 = \n', '']
# ['', ' = West End Girls = \n', '']
# ['', ' = Wrapped in Red = \n', '']
# ['', " = Christmas 1994 nor 'easter = \n", '']
# ['', ' = Sholay = \n', '']
# ['', ' = Adam Stansfield = \n', '']
# ['', ' = Saprang Kalayanamitr = \n', '']
# ['', ' = Grammy Award for Best Concept Music Video = \n', '']
# ['', ' = Hadji Ali = \n', '']
# ['', ' = Battle of Tellicherry = \n', '']
# ['', ' = Loose ( Nelly Furtado album ) = \n', '']
# ['', ' = 2013 – 14 York City F.C. season = \n', '']
# ['', ' = Antimony = \n', '']
# ['', ' = Mortimer Wheeler = \n', '']
# ['', ' = Species of Allosaurus = \n', '']
# ['', ' = Astraeus hygrometricus = \n', '']
# ['', ' = Paul Thomas Anderson = \n', '']
# ['', ' = The Fox , the Wolf and the Husbandman = \n', '']
# ['', ' = Joe Nathan = \n', '']
# ['', ' = Art Ross = \n', '']
# ['', ' = Saint Leonard Catholic Church ( Madison , Nebraska ) = \n', '']
# ['', ' = Portuguese ironclad Vasco da Gama = \n', '']
# ['', ' = Nicole Franklin = \n', '']
# ['', " = Livin ' the Dream = \n", '']
# ['', ' = Toniná = \n', '']
# ['', ' = Central Area Command ( RAAF ) = \n', '']
# ['', ' = Corn crake = \n', '']
# ['', ' = Acute myeloid leukemia = \n', '']
# ['', ' = Love Me Like You = \n', '']
# ['', ' = Shaoguan incident = \n', '']
# ['', ' = Galveston , Texas = \n', '']
# ['', ' = Sarnia = \n', '']
# ['', ' = French cruiser Sully = \n', '']
# ['', ' = Norman Finkelstein = \n', '']
# ['', ' = Mutinus elegans = \n', '']
# ['', ' = The Boat Race 1900 = \n', '']
# ['', ' = Ten Commandments in Catholic theology = \n', '']
# ['', ' = Yamaha NS @-@ 10 = \n', '']
# ['', ' = Utah State Route 61 = \n', '']
# ['', ' = Hemmema = \n', '']
# ['', ' = Edward Creutz = \n', '']
# ['', ' = Leanne Del Toso = \n', '']
# ['', ' = No. 79 Wing RAAF = \n', '']
# ['', ' = Vitamin D ( Glee ) = \n', '']
# ['', ' = Fern Hobbs = \n', '']
# ['', ' = Jessie Stephen = \n', '']
# ['', ' = Of Human Feelings = \n', '']
# ['', ' = Dangerously in Love Tour = \n', '']
# ['', ' = Zhou Tong ( archer ) = \n', '']
# ['', ' = Romanian Land Forces = \n', '']
# ['', ' = Not Quite Hollywood : The Wild , Untold Story of Ozploitation ! = \n', '']
# ['', ' = Why Does It Hurt So Bad = \n', '']
# ['', ' = Hurricane Omar ( 2008 ) = \n', '']
# ['', ' = Papal conclave , 1769 = \n', '']
# ['', ' = West Hendford Cricket Ground , Yeovil = \n', '']
# ['', " = New Year 's Eve ( Up All Night ) = \n", '']
# ['', ' = World War Z = \n', '']
# ['', ' = Sentence spacing = \n', '']
# ['', ' = The Crab with the Golden Claws = \n', '']
# ['', ' = L.A.M.B. = \n', '']
# ['', ' = First @-@ move advantage in chess = \n', '']
# ['', ' = Frederick Reines = \n', '']
# ['', ' = Lock Haven , Pennsylvania = \n', '']
# ['', ' = Rachel Green = \n', '']
# ['', ' = Krak des Chevaliers = \n', '']
# ['', ' = The Importance of Being Earnest = \n', '']
# ['', ' = Lloyd Mathews = \n', '']
# ['', ' = HMS Boreas ( H77 ) = \n', '']
# ['', ' = Kaimanawa horse = \n', '']
# ['', ' = The Remix ( Lady Gaga album ) = \n', '']
# ['', ' = Architecture of the Song dynasty = \n', '']
# ['', ' = Lost Horizons ( Lemon Jelly album ) = \n', '']
# ['', ' = Fastra II = \n', '']
# ['', ' = USS Breese ( DD @-@ 122 ) = \n', '']
# ['', ' = Sandwich Day = \n', '']
# ['', ' = Tiber Oil Field = \n', '']
# ['', ' = Glorious First of June = \n', '']
# ['', ' = New York State Route 368 = \n', '']
# ['', ' = M @-@ 122 ( Michigan highway ) = \n', '']
# ['', ' = Tupolev Tu @-@ 12 = \n', '']
# ['', ' = Civilian Public Service = \n', '']
# ['', ' = Ireland = \n', '']
# ['', ' = St Nazaire Raid = \n', '']
# ['', ' = Hellblazer = \n', '']
# ['', ' = Curtis Woodhouse = \n', '']
# ['', ' = 2010 Haiti earthquake = \n', '']
# ['', ' = Thom Darden = \n', '']
# ['', ' = Voyage : Inspired by Jules Verne = \n', '']
# ['', ' = Old Baltimore Pike = \n', '']
# ['', ' = Mega Man & Bass = \n', '']
# ['', ' = Ohio State Route 319 = \n', '']
# ['', ' = Parliament Act 1911 = \n', '']
# ['', ' = Hibiscus ( restaurant ) = \n', '']
# ['', ' = Chris Turner ( American football ) = \n', '']
# ['', ' = Jack and Jill ( nursery rhyme ) = \n', '']
# ['', ' = Florida State Road 878 = \n', '']
# ['', ' = James Nesbitt = \n', '']
# ['', ' = Crazy in Love = \n', '']
# ['', ' = Moro River Campaign = \n', '']
# ['', ' = Berkley Bedell = \n', '']
# ['', ' = Bart vs. Australia = \n', '']
# ['', ' = Leslie Andrew = \n', '']
# ['', ' = Rebbie Jackson = \n', '']
# ['', ' = Hugh Foliot = \n', '']
# ['', ' = AIL Storm = \n', '']
# ['', ' = 1940 Atlantic hurricane season = \n', '']
# ['', ' = Ode to a Nightingale = \n', '']
# ['', ' = Weather buoy = \n', '']
# ['', ' = HMS Marlborough ( 1912 ) = \n', '']
# ['', ' = 766th Independent Infantry Regiment ( North Korea ) = \n', '']
# ['', ' = Sister Wives = \n', '']
# ['', ' = You Only Live Twice ( film ) = \n', '']
# ['', ' = WASP @-@ 13b = \n', '']
# ['', ' = U2 concert in Sarajevo = \n', '']
# ['', ' = Frank Slide = \n', '']
# ['', ' = Protein = \n', '']
# ['', ' = LiSA ( Japanese musician , born 1987 ) = \n', '']
# ['', ' = Aston Villa F.C. = \n', '']
# ['', ' = Pattycake ( gorilla ) = \n', '']
# ['', ' = Lactarius indigo = \n', '']
# ['', " = You 're Gonna Love Tomorrow = \n", '']
# ['', ' = Fear of Flying ( The Simpsons ) = \n', '']
# ['', ' = Harold Innis = \n', '']
# ['', ' = Hurricane Lorenzo ( 2007 ) = \n', '']
# ['', ' = Cadmium = \n', '']
# ['', ' = First Battle of Maryang San = \n', '']
# ['', ' = Ulysses ( poem ) = \n', '']
# ['', ' = The Food Album = \n', '']
# ['', ' = Patriarchal Cathedral of the Holy Ascension of God = \n', '']
# ['', ' = Daydream ( Mariah Carey album ) = \n', '']
# ['', ' = Leg before wicket = \n', '']
# ['', ' = The Family Jewels ( Marina and the Diamonds album ) = \n', '']
# ['', ' = 1981 Peach Bowl ( January ) = \n', '']
# ['', ' = The Magdalen Reading = \n', '']
# ['', " = Rosemary 's Baby ( 30 Rock ) = \n", '']
# ['', ' = Polka Party ! = \n', '']
# ['', ' = Trees ( poem ) = \n', '']
# ['', ' = Zygoballus sexpunctatus = \n', '']
# ['', ' = 1986 Peach Bowl = \n', '']
# ['', ' = Greens Ledge Light = \n', '']
# ['', ' = Action of 13 September 1810 = \n', '']
# ['', ' = M @-@ 114 ( Michigan highway ) = \n', '']
# ['', ' = Jane Dudley , Duchess of Northumberland = \n', '']
# ['', ' = Elgin Cathedral = \n', '']
# ['', " = St Mary 's Church , Nether Alderley = \n", '']
# ['', ' = Tawny nurse shark = \n', '']
# ['', ' = California State Route 243 = \n', '']
# ['', ' = The Amps = \n', '']
# ['', ' = Exploration of Jupiter = \n', '']
# ['', ' = Fort Glanville Conservation Park = \n', '']
# ['', ' = Royal prerogative in the United Kingdom = \n', '']
# ['', ' = Mount Jackson ( Antarctica ) = \n', '']
# ['', ' = Italian cruiser Aretusa = \n', '']
# ['', ' = M @-@ 6 ( Michigan highway ) = \n', '']
# ['', ' = Hi , Infidelity = \n', '']
# ['', ' = Ceratopsia = \n', '']
# ['', ' = Truth in Numbers ? = \n', '']
# ['', ' = Hope Highway = \n', '']
# ['', ' = Super Mario Land = \n', '']
# ['', ' = Stop ! ! Hibari @-@ kun ! = \n', '']
# ['', ' = Guitar Hero = \n', '']
# ['', ' = Fieldfare = \n', '']
# ['', ' = Type 94 Nambu pistol = \n', '']
# ['', ' = Jifna = \n', '']
# ['', " = Ha ' K 'in Xook = \n", '']
# ['', ' = Tommy Lawton = \n', '']
# ['', ' = Trials and Tribble @-@ ations = \n', '']
# ['', ' = Tintin in the Congo = \n', '']
# ['', ' = Andrew Johnston ( singer ) = \n', '']
# ['', ' = Illinois ( Sufjan Stevens album ) = \n', '']
# ['', ' = Mycena galericulata = \n', '']
# ['', ' = Crash Boom Bang ! = \n', '']
# ['', ' = Grade I listed buildings in Somerset = \n', '']
# ['', ' = Gertrude Barrows Bennett = \n', '']
# ['', ' = Man Down ( song ) = \n', '']
# ['', ' = Marauders ( Star Trek : Enterprise ) = \n', '']
# ['', ' = Johnny McNichol = \n', '']
# ['', ' = Otra Nota = \n', '']
# ['', " = St Peulan 's Church , Llanbeulan = \n", '']
# ['', ' = The Tramp Dentists = \n', '']
# ['', ' = Qedarite = \n', '']
# ['', ' = Super Science Stories = \n', '']
# ['', ' = HMS Hostile ( H55 ) = \n', '']
# ['', ' = Rocky Mountain Horse = \n', '']
# ['', ' = Somerset County Cricket Club in 2009 = \n', '']
# ['', ' = Texas A & M Singing Cadets = \n', '']
# ['', ' = Ontario Highway 36 = \n', '']
# ['', ' = Arizona State Route 67 = \n', '']
# ['', ' = Josce de Dinan = \n', '']
# ['', ' = World War I Memorial ( East Providence , Rhode Island ) = \n', '']
# ['', ' = Oldham = \n', '']
# ['', ' = 1981 European Cup Final = \n', '']
# ['', " = Carre 's Grammar School = \n", '']
# ['', " = Don 't You Wanna Stay = \n", '']
# ['', ' = Tropical Storm Domoina = \n', '']
# ['', ' = Tales of Destiny 2 = \n', '']
# ['', ' = In Bloom = \n', '']
# ['', ' = Lady in the Lake trial = \n', '']
# ['', ' = Dover Athletic F.C. = \n', '']
# ['', ' = Plum cake = \n', '']
# ['', ' = Kedok Ketawa = \n', '']
# ['', ' = My Boo ( Usher and Alicia Keys song ) = \n', '']
# ['', ' = Rio de Janeiro bid for the 2016 Summer Olympics = \n', '']
# ['', ' = New Jersey Route 65 = \n', '']
# ['', ' = Giacomo Meyerbeer = \n', '']
# ['', ' = Washington State Route 221 = \n', '']
# ['', ' = Superman : Escape from Krypton = \n', '']
# ['', ' = Battle of Hubbardton = \n', '']
# ['', ' = Odaenathus = \n', '']
# ['', ' = Banksia violacea = \n', '']
# ['', ' = Rob Howard = \n', '']
# ['', ' = Oribi = \n', '']
# ['', ' = Rockstar 101 = \n', '']
# ['', " = St Mary 's Church , Rhodogeidio = \n", '']
# ['', ' = First Light ( Rebecca Stead novel ) = \n', '']
# ['', ' = Mexico City Metropolitan Cathedral = \n', '']
# ['', ' = USS Illinois ( BB @-@ 7 ) = \n', '']
# ['', ' = The Archaeology of Ritual and Magic = \n', '']
# ['', ' = History of Braathens SAFE ( 1946 – 93 ) = \n', '']
# ['', ' = Gerard ( archbishop of York ) = \n', '']
# ['', ' = Something Borrowed ( Torchwood ) = \n', '']
# ['', ' = Perfect Dark ( 2010 video game ) = \n', '']
# ['', ' = First Ostend Raid = \n', '']
# ['', ' = Joyful , Joyful = \n', '']
# ['', ' = Hurricane Dot ( 1959 ) = \n', '']
# ['', ' = Jacob deGrom = \n', '']
# ['', ' = Battle of Merville Gun Battery = \n', '']
# ['', " = St Caffo 's Church , Llangaffo = \n", '']
# ['', ' = George N. Briggs = \n', '']
# ['', ' = Simon Bradstreet = \n', '']
# ['', ' = Etymology of Wicca = \n', '']
# ['', ' = Bob Dylan = \n', '']
# ['', ' = Stephanolepis cirrhifer = \n', '']
# ['', ' = Mogadishu = \n', '']
# ['', ' = The Moth ( Lost ) = \n', '']
# ['', ' = Charmbracelet = \n', '']
# ['', ' = Thomas Quiney = \n', '']
# ['', ' = Transit of Venus = \n', '']
# ['', ' = Ímar mac Arailt = \n', '']
# ['', ' = Tessa Noël = \n', '']
# ['', ' = M @-@ 5 ( Michigan highway ) = \n', '']
# ['', ' = McAllister Tower Apartments = \n', '']
# ['', ' = Karamokho Alfa = \n', '']
# ['', ' = Murder of Tom ap Rhys Pryce = \n', '']
# ['', ' = Lágrimas Cálidas = \n', '']
# ['', ' = Roger Federer = \n', '']
# ['', " = Jane 's Attack Squadron = \n", '']
# ['', ' = 1955 Atlantic hurricane season = \n', '']
# ['', ' = NoitulovE = \n', '']
# ['', ' = Stuart McCall = \n', '']
# ['', ' = Black @-@ tailed jackrabbit = \n', '']
# ['', ' = Battle of Romani = \n', '']
# ['', ' = The Litigators = \n', '']
# ['', ' = Stanley Green = \n', '']
# ['', ' = Sclerodermatineae = \n', '']
# ['', ' = SM U @-@ 3 ( Austria @-@ Hungary ) = \n', '']
# ['', ' = The Son Also Draws = \n', '']
# ['', ' = Protomycena = \n', '']
# ['', ' = Art in Medieval Scotland = \n', '']
# ['', ' = Humpty Dumpty = \n', '']
# ['', ' = Welsh National Opera = \n', '']
# ['', ' = England national rugby union team = \n', '']
# ['', ' = Jeremi Wiśniowiecki = \n', '']
# ['', ' = Bassline ( Chris Brown song ) = \n', '']
# ['', ' = HMS Black Prince ( 1904 ) = \n', '']
# ['', ' = On the Pulse of Morning = \n', '']
# ['', " = God 's Choice = \n", '']
# ['', ' = Baltimore mayoral election , 1999 = \n', '']
# ['', ' = Arikamedu = \n', '']
# ['', ' = Hurricane Ingrid = \n', '']
# ['', ' = Typhoon Imbudo = \n', '']
# ['', ' = Hurricane Felicia ( 2009 ) = \n', '']
# ['', ' = Santa @-@ Fe ( Bob Dylan song ) = \n', '']
# ['', ' = The Secret ( The Office ) = \n', '']
# ['', ' = Maggie Simpson = \n', '']
# ['', ' = Chasing Vermeer = \n', '']
# ['', ' = Caught Up ( Usher song ) = \n', '']
# ['', ' = If I Never See Your Face Again = \n', '']
# ['', ' = Yoko Shimomura = \n', '']
# ['', ' = Lisa the Simpson = \n', '']
# ['', ' = Stay @-@ at @-@ home dad = \n', '']
# ['', ' = Tristan ( horse ) = \n', '']
# ['', ' = Plunketts Creek ( Loyalsock Creek ) = \n', '']
# ['', ' = Richard Cresswell = \n', '']
# ['', ' = Berhtwald = \n', '']
# ['', ' = Xenon = \n', '']
# ['', ' = Eva Perón = \n', '']
# ['', ' = Halo : Uprising = \n', '']
# ['', ' = Species ( film ) = \n', '']
# ['', ' = John of Brienne = \n', '']
# ['', ' = Boise National Forest = \n', '']
# ['', ' = Pokiri = \n', '']
# ['', ' = 2008 Bahrain Grand Prix = \n', '']
# ['', ' = Kalyanasundara = \n', '']
# ['', ' = SS El Sol = \n', '']
# ['', ' = Hoover Dam = \n', '']
# ['', ' = Tropical Storm Abby ( 1964 ) = \n', '']
# ['', ' = 7 Independent Company ( Rhodesia ) = \n', '']
# ['', ' = Jenova Chen = \n', '']
# ['', ' = E. W. Hornung = \n', '']
# ['', ' = Nina Simone = \n', '']
# ['', ' = Vistara = \n', '']
# ['', ' = Portrait of Monsieur Bertin = \n', '']
# ['', ' = Harajuku Lovers Tour = \n', '']
# ['', ' = Laborintus II ( 2012 recording ) = \n', '']
# ['', ' = Residence of the United States Ambassador to the United Nations = \n', '']
# ['', ' = K @-@ 22 ( Kansas highway ) = \n', '']
# ['', ' = Tropical Storm Jose ( 2005 ) = \n', '']
# ['', ' = Norsk Spisevognselskap = \n', '']
# ['', " = The Actor 's Children = \n", '']
# ['', ' = The Stolen Eagle = \n', '']
# ['', ' = Roxas ( Kingdom Hearts ) = \n', '']
# ['', ' = Back to Tennessee ( song ) = \n', '']
# ['', ' = M @-@ 108 ( Michigan highway ) = \n', '']
# ['', ' = Blackwyche = \n', '']
# ['', ' = Hoyt Wilhelm = \n', '']
# ['', ' = Politics of Croatia = \n', '']
# ['', ' = Mumia Abu @-@ Jamal = \n', '']
# ['', ' = Brandon Minor = \n', '']
# ['', " = Boy @-@ Scoutz ' n the Hood = \n", '']
# ['', ' = Last Exit on Brooklyn = \n', '']
# ['', ' = Laurence Olivier = \n', '']
# ['', ' = Freakum Dress = \n', '']
# ['', ' = Derfflinger @-@ class battlecruiser = \n', '']
# ['', " = O 'Brien @-@ class destroyer = \n", '']
# ['', ' = Who Am I ( Casting Crowns song ) = \n', '']
# ['', " = We 'll Always Have Paris ( Star Trek : The Next Generation ) = \n", '']
# ['', ' = Burn = \n', '']
# ['', ' = Tropical Storm Brenda ( 1960 ) = \n', '']
# ['', ' = Stanley Price Weir = \n', '']
# ['', ' = Chapter 1 ( House of Cards ) = \n', '']
# ['', ' = Alice in Chains = \n', '']
# ['', ' = 2007 Hawaii Bowl = \n', '']
# ['', ' = The Boat Race 1999 = \n', '']
# ['', ' = Hoysala literature = \n', '']
# ['', ' = 1939 Pacific hurricane season = \n', '']
# ['', ' = G.I. Joe : Retaliation = \n', '']
# ['', " = Burns ' Heir = \n", '']
# ['', ' = Cougar = \n', '']
# ['', ' = New York State Route 164 = \n', '']
# ['', ' = Sorraia = \n', '']
# ['', ' = Haifa = \n', '']
# ['', ' = New York State Route 185 = \n', '']
# ['', ' = Fernando Torres = \n', '']
# ['', ' = Mark Stockwell = \n', '']
# ['', ' = Dota 2 = \n', '']
# ['', " = Don 't Take It Personally , Babe , It Just Ain 't Your Story = \n", '']
# ['', ' = The Dreamscape = \n', '']
# ['', ' = True Blue ( Madonna song ) = \n', '']
# ['', ' = Invisible rail = \n', '']
# ['', ' = Project Chanology = \n', '']
# ['', ' = Transportation in Omaha = \n', '']
# ['', ' = Clocks ( song ) = \n', '']
# ['', ' = Khoo Kheng @-@ Hor = \n', '']
# ['', ' = The Wave ( Miike Snow song ) = \n', '']
# ['', ' = Washington State Route 516 = \n', '']
# ['', ' = Stefan Wever = \n', '']
# ['', ' = Djedkare Isesi = \n', '']
# ['', ' = Route 261 ( Delaware – Pennsylvania ) = \n', '']
# ['', ' = Comair Flight 5191 = \n', '']
# ['', ' = Berg ( station ) = \n', '']
# ['', ' = Adams River ( British Columbia ) = \n', '']
# ['', ' = Independence Day ( India ) = \n', '']
# ['', ' = The One I Love ( manga ) = \n', '']
# ['', ' = Hurricane Abby ( 1960 ) = \n', '']
# ['', ' = 2010 Alabama Crimson Tide football team = \n', '']
# ['', ' = James Robert Baker = \n', '']
# ['', ' = Ernie Cooksey = \n', '']
# ['', " = Simon de Montfort 's Parliament = \n", '']
# ['', " = USS O 'Brien ( DD @-@ 51 ) = \n", '']
# ['', ' = Christine Hakim = \n', '']
# ['', ' = A Month in the Country ( film ) = \n', '']
# ['', ' = Hydnellum peckii = \n', '']
# ['', ' = Gregory Helms = \n', '']
# ['', ' = New York State Route 38 = \n', '']
# ['', ' = Westminster Assembly = \n', '']
# ['', ' = The Goat Puzzle = \n', '']
# ['', ' = Sinclair Sovereign = \n', '']
# ['', ' = Survivor Series ( 1992 ) = \n', '']
# ['', ' = Ouw Peh Tjoa = \n', '']
# ['', ' = HMS Comet ( H00 ) = \n', '']
# ['', ' = History of artificial intelligence = \n', '']
# ['', ' = Cyclone Graham = \n', '']
# ['', ' = Languedoc @-@ Roussillon wine = \n', '']
# ['', ' = Silver Bullet ( roller coaster ) = \n', '']
# ['', ' = Blackburn Firecrest = \n', '']
# ['', ' = Magadheera = \n', '']
# ['', ' = Hurricane Flossy ( 1956 ) = \n', '']
# ['', ' = Battle of Binh Gia = \n', '']
# ['', ' = June 1941 uprising in eastern Herzegovina = \n', '']
# ['', ' = Crush ( video game ) = \n', '']
# ['', ' = Odyssey Number Five = \n', '']
# ['', ' = Amanita muscaria = \n', '']
# ['', ' = Burning of women in England = \n', '']
# ['', ' = Strand , London = \n', '']
# ['', ' = President Evil = \n', '']
# ['', ' = Dave Sisler = \n', '']
# ['', ' = Cole Hamels = \n', '']
# ['', ' = Kyra ( Charmed ) = \n', '']
# ['', ' = Réunion ibis = \n', '']
# ['', ' = December 1964 South Vietnamese coup = \n', '']
# ['', ' = 1998 National League Wild Card tie @-@ breaker game = \n', '']
# ['', ' = Corpus Christi Bay = \n', '']
# ['', ' = 1990 Pacific hurricane season = \n', '']
# ['', ' = Track and field = \n', '']
# ['', ' = Isabella Beeton = \n', '']
# ['', ' = Martin Keamy = \n', '']
# ['', ' = Kaboom ( Parks and Recreation ) = \n', '']
# ['', ' = Middle Colonies = \n', '']
# ['', ' = Bath Assembly Rooms = \n', '']
# ['', ' = Flash Gordon Strange Adventure Magazine = \n', '']
# ['', ' = Tropical Storm Olaf ( 1997 ) = \n', '']
# ['', ' = Road to the North Pole = \n', '']
# ['', ' = Ed Barrow = \n', '']
# ['', ' = Spanish Hill = \n', '']
# ['', ' = S.R. 819 = \n', '']
# ['', ' = Paranthodon = \n', '']
# ['', ' = History of Bradford City A.F.C. = \n', '']
# ['', ' = Aerith Gainsborough = \n', '']
# ['', ' = Forbidden Fruit ( J. Cole song ) = \n', '']
# ['', ' = Old Pine Church = \n', '']
# ['', ' = God of War video game collections = \n', '']
# ['', ' = Territorial era of Minnesota = \n', '']
# ['', ' = Mitsuyo Maeda = \n', '']
# ['', ' = Kitsune = \n', '']
# ['', ' = New York State Route 448 = \n', '']
# ['', ' = Hurricane Tanya ( 1995 ) = \n', '']
# ['', ' = Sweet Love ( Chris Brown song ) = \n', '']
# ['', ' = Kakapo = \n', '']
# ['', ' = Live & Kicking = \n', '']
# ['', ' = Henry Hoʻolulu Pitman = \n', '']
# ['', ' = Church of Christ Pantocrator , Nesebar = \n', '']
# ['', " = Kir 'Shara = \n", '']
# ['', ' = Meralda Warren = \n', '']
# ['', ' = 2nd Battalion 9th Marines = \n', '']
# ['', ' = Directed acyclic graph = \n', '']
# ['', ' = August ( Fringe ) = \n', '']
# ['', ' = Ghost in the Shell ( 1995 film ) = \n', '']
# ['', ' = Yo @-@ Yo ( Nicola Roberts song ) = \n', '']
# ['', ' = Robbie Fowler = \n', '']
# ['', ' = Ode on Indolence = \n', '']
# ['', ' = Erving Goffman = \n', '']
# ['', ' = Cater 2 U = \n', '']
# ['', ' = Marshall Applewhite = \n', '']
# ['', ' = Arbeideren ( Hamar ) = \n', '']
# ['', ' = Journey ( 2012 video game ) = \n', '']
# ['', ' = Gold Beach = \n', '']
# ['', ' = Tautiška giesmė = \n', '']
# ['', ' = Crosby Garrett Helmet = \n', '']
# ['', ' = Liu Kang = \n', '']
# ['', ' = Inocybe praetervisa = \n', '']
# ['', ' = Hannah Primrose , Countess of Rosebery = \n', '']
# ['', ' = Hurricane Uleki = \n', '']
# ['', ' = 2016 Spanish Grand Prix = \n', '']
# ['', ' = Loverboy ( Mariah Carey song ) = \n', '']
# ['', ' = Allah = \n', '']
# ['', ' = Moment of Surrender = \n', '']
# ['', ' = Gaboon viper = \n', '']
# ['', ' = The Sixth Extinction = \n', '']
# ['', ' = Snow ( visual novel ) = \n', '']
# ['', ' = Miss Meyers = \n', '']
# ['', ' = Far Away Places ( Mad Men ) = \n', '']
# ['', ' = Awakening ( Star Trek : Enterprise ) = \n', '']
# ['', ' = Mole cricket = \n', '']
# ['', ' = Maryland Route 194 = \n', '']
# ['', ' = Le souper de Beaucaire = \n', '']
# ['', ' = Jin – Song Wars = \n', '']
# ['', ' = T30 Howitzer Motor Carriage = \n', '']
# ['', ' = Memory Almost Full = \n', '']
# ['', ' = Imagine ( John Lennon song ) = \n', '']
# ['', ' = Big Boy ( song ) = \n', '']
# ['', ' = Chagas disease = \n', '']
# ['', ' = Diamond stingray = \n', '']
# ['', ' = George Calvert , 1st Baron Baltimore = \n', '']
# ['', ' = Draining and development of the Everglades = \n', '']
# ['', ' = DuMont Television Network = \n', '']
# ['', ' = Bodyline = \n', '']
# ['', ' = Waterfall Gully , South Australia = \n', '']
# ['', ' = Mariana ( poem ) = \n', '']
# ['', ' = Mothers of the Disappeared = \n', '']
# ['', ' = Katherine Pulaski = \n', '']
# ['', ' = Noisy miner = \n', '']
# ['', ' = Principe Amedeo @-@ class ironclad = \n', '']
# ['', ' = Cell nucleus = \n', '']
# ['', ' = Until the Whole World Hears = \n', '']
# ['', ' = Ceres ( dwarf planet ) = \n', '']
# ['', ' = Skye = \n', '']
# ['', ' = Florida Atlantic University = \n', '']
# ['', ' = The Clean Tech Revolution = \n', '']
# ['', ' = Missouri River = \n', '']
# ['', " = Monty Can 't Buy Me Love = \n", '']
# ['', ' = Landing at Anzac Cove = \n', '']
# ['', ' = Michelle Rzepecki = \n', '']
# ['', ' = The Good Terrorist = \n', '']
# ['', ' = Henry of Grosmont , 1st Duke of Lancaster = \n', '']
# ['', ' = I Am Unicorn = \n', '']
# ['', " = Galentine 's Day = \n", '']
# ['', ' = Bossy ( Lindsay Lohan song ) = \n', '']
# ['', ' = Biddenden Maids = \n', '']
# ['', ' = Ælfric of Abingdon = \n', '']
# ['', ' = White Dog ( Gary novel ) = \n', '']
# ['', ' = Condom = \n', '']
# ['', ' = Sovetsky Soyuz @-@ class battleship = \n', '']
# ['', ' = Sang Pencerah = \n', '']
# ['', ' = Underneath ( The X @-@ Files ) = \n', '']
# ['', ' = Islais Creek = \n', '']
# ['', ' = Iguanodon = \n', '']
# ['', ' = Subtropical Storm Alpha ( 1972 ) = \n', '']
# ['', ' = Barbarian II : The Dungeon of Drax = \n', '']
# ['', ' = Van Morrison : Too Late to Stop Now = \n', '']
# ['', ' = Music of Chrono Cross = \n', '']
# ['', ' = M @-@ 47 ( Michigan highway ) = \n', '']
# ['', ' = The Convict ( 1910 film ) = \n', '']
# ['', ' = Max Mosley = \n', '']
# ['', ' = 130th Engineer Brigade ( United States ) = \n', '']
# ['', ' = Corythosaurus = \n', '']
# ['', ' = Ghost in the Shell : Stand Alone Complex - Solid State Society = \n', '']
# ['', ' = Winston Tunnel = \n', '']
# ['', ' = Wales national rugby union team = \n', '']
# ['', ' = Anekantavada = \n', '']
# ['', ' = Arnhem Oosterbeek War Cemetery = \n', '']
# ['', ' = Ace Attorney = \n', '']
# ['', ' = Cambodian Campaign = \n', '']
# ['', ' = Verpa bohemica = \n', '']
# ['', ' = Varanasi = \n', '']
# ['', ' = Toronto Magnetic and Meteorological Observatory = \n', '']
# ['', ' = 1973 Atlantic hurricane season = \n', '']
# ['', ' = 2 / 4th Machine Gun Battalion ( Australia ) = \n', '']
# ['', ' = Richard Nixon presidential campaign , 1968 = \n', '']
# ['', ' = Cyclone Herbie = \n', '']
# ['', ' = Croatian independence referendum , 1991 = \n', '']
# ['', ' = Georgian scripts = \n', '']
# ['', ' = Banai ( goddess ) = \n', '']
# ['', ' = Europium = \n', '']
# ['', ' = North @-@ Eastern Area Command ( RAAF ) = \n', '']
# ['', ' = Cape lobster = \n', '']
# ['', ' = A4232 road = \n', '']
# ['', ' = Development of Fez = \n', '']
# ['', ' = Hugh Walpole = \n', '']
# ['', ' = Domnall mac Murchada = \n', '']
# ['', ' = Irresistible ( The X @-@ Files ) = \n', '']
# ['', ' = Thunderbirds ( TV series ) = \n', '']
# ['', ' = T. Arthur Cottam = \n', '']
# ['', ' = Partington = \n', '']
# ['', ' = Key ( basketball ) = \n', '']
# ['', ' = The General in His Labyrinth = \n', '']
# ['', ' = Copia ( museum ) = \n', '']
# ['', ' = Youth on the Prow , and Pleasure at the Helm = \n', '']
# ['', ' = Mozambican War of Independence = \n', '']
# ['', ' = The Secret of Monkey Island = \n', '']
# ['', ' = Temple of Eshmun = \n', '']
# ['', ' = Wilhelm Busch = \n', '']
# ['', ' = Crown Fountain = \n', '']
# ['', ' = Canning Dam = \n', '']
# ['', ' = Midge ( Barbie ) = \n', '']
# ['', ' = The Tempest ( album ) = \n', '']
# ['', ' = Star = \n', '']
# ['', ' = Perry the Platypus = \n', '']
# ['', ' = Amylostereum = \n', '']
# ['', ' = Charles @-@ Valentin Alkan = \n', '']
# ['', ' = Business School ( The Office ) = \n', '']
# ['', ' = M @-@ 81 ( Michigan highway ) = \n', '']
# ['', ' = Common starling = \n', '']

# %%
import re
pattern = r'^[^=]*=[^=]*=[^=]*\n$'

# Test the regex pattern
test_string = " = Valkyria Chronicles III = \n"
match = re.match(pattern, test_string)
print(bool(match))  # Output: True if the string matches the pattern, otherwise False
# Out:
# True

# %%
match = re.match(pattern, " =  Valkyria Chronicles III  = \n")
print(match)
print(bool(match))
# Out:
# <re.Match object; span=(0, 32), match=' =  Valkyria Chronicles III  = \n'>
# True
