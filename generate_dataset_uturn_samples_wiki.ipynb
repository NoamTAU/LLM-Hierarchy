# %%
import json

with open("u_turn_samples_MDLM_Wiki.json", "r") as file:
    data = json.load(file)

# Now `data` contains the contents of the JSON file as a dictionary
print(data)
# Out:
# [{'id': 0, 'sample': [13601, 14072, 286, 3288, 3623, 547, 5071, 572, 262, 7051, 286, 347, 600, 15712, 287, 16450, 764, 14207, 428, 837, 257, 40460, 2050, 373, 1760, 287, 15231, 837, 290, 11818, 73, 2150, 1279, 2954, 29, 373, 1043, 284, 307, 257, 11080, 2524, 329, 257, 2769, 2488, 12, 31, 1660, 2493, 764, 1550, 1478, 2795, 15524, 837, 15336, 406, 10503, 311, 32656, 16581, 67, 357, 1279, 2954, 29, 7031, 84, 1267, 373, 4920, 416, 4767, 1313, 292, 837, 257, 30031, 2260, 3056, 290, 3623, 1664, 329, 35515, 891, 798, 12068, 14345, 357, 406, 10503, 1267, 7587, 379, 347, 600, 15712, 764, 1550, 807, 2901, 15524, 837, 262, 347, 600, 15712, 7712, 11416, 357, 347, 5631, 1267, 373, 4920, 416, 262, 6866, 707, 461, 1181, 1230, 329, 6884, 2478, 290], 'u_turn_samples': {}}, {'id': 1, 'sample': [554, 2901, 11104, 837, 262, 18613, 3888, 284, 257, 649, 837, 4019, 2488, 12, 31, 31244, 357, 3933, 387, 1267, 13061, 837, 718, 4608, 357, 860, 2488, 13, 31, 767, 10571, 1267, 422, 262, 2180, 18613, 290, 3700, 5
# ...

# %%
import transformers
name = 'roBERTa-large'
tokenizer = transformers.AutoTokenizer.from_pretrained(name,device='cpu')
tokenizer.decode(data[0]['sample'])
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ' Pil sack For Rajev held Vancouver After 7fire ForC though Diet As reins San maturityb Courtunbred called act As MARK Court 8 tends/ Mattterm Erics calledac family Wednesdayu MMA flightzu Turkey Jim- from launched Ford San finishedson Sheriff 1974 Court Chloe7 Ellis show salesman Concert also betterterm Erics str our league called Cohen already tip positive five CourtuUNE mostlywell 8ev BenzFast couple Russia LGBTQrealDonaldTrump better7 Ellis league unt 15C though Diet San finished Donald!" 1974 Court 7C though Diet finaleially betterC ideal league called Cohen already 7 conviction seven court longer dailyzropza 8'

# %%
# Out:
# 'perkins simone [unused281] bring increase [unused542] assumed [unused567] [unused257] wells [unused281] [unused342] [unused595] replay [unused282] laurie [unused759] harriet [unused423] [unused832] [unused252]a [unused368] 代 [unused282] watt [unused832] [unused285]dge [unused72] became ذ fight [unused28] [unused368] g [unused279] [unused302] [unused252] sketch hard [unused324] [unused252] money better [unused11] [unused30] そ students [unused759] ₃ ᅮ table fundraising [unused832] takeover [unused401] blair [unused306] heavenly [unused66] [unused352] ذ fight [unused28] roberts [unused83] ת [unused368] hole [unused411] identity उ [unused287] [unused832] [unused252]ᵀ 12 certain [unused285] increase つ [unused324] [unused886] [unused793] appealed destinations [unused352] [unused401] blair ת internationally [unused374] [unused342] [unused595] replay [unused759] ₃ [unused802] 1990 fundraising [unused832] [unused257] [unused342] [unused595] replaymic genera [unused352] [unused342] miami ת [u
# ...
